# %%
import streamlit as st
from path import Path
from datetime import date
import pandas as pd

# %%
import yfinance as yf
from prophet import Prophet
from fbprophet.plot import plot_plotly
from plotly import graph_objs as go

START = "2016-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

st.title("Anthon Stock Predictor")
stocks = ("AMZN","GOOG", "NFLX", "BTC-USD", "ETH-USD")

# Set number of years to predict
n_years = 3
period = n_years * 365

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

##Set stock to analyze
selected_stock = "AMZN"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("AMAZON:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# 2022-02-13 21:39:55.861
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\kubip\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2022-02-13 21:39:56.041 Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2022-02-13 21:39:56.043 NumExpr defaulting to 8 threads.
# [*********************100%***********************]  1 of 1 completed
# 2022-02-13 21:39:57.186 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# AMAZON:

# %%
print('AMZN Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# AMZN Daily plot:

# %%
##Set stock to analyze
selected_stock = "GOOG"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("GOOGLE:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2022-02-13 21:40:06.654 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# GOOGLE:

# %%
print('GOOG Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# GOOG Daily plot:

# %%
##Set stock to analyze
selected_stock = "NFLX"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("NETFLIX:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2022-02-13 21:40:12.764 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# NETFLIX:

# %%
print('NFLX Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# NFLX Daily plot:

# %%
##Set stock to analyze
selected_stock = "BTC-USD"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("BITCOIN:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2022-02-13 21:40:18.731 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# BITCOIN:

# %%
print('BTC Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# BTC Daily plot:

# %%
##Set stock to analyze
selected_stock = "ETH-USD"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("ETH:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2022-02-13 21:40:25.907 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ETH:

# %%
print('ETH Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# ETH Daily plot:
